# %%
import pandas as pd
import numpy as np
import sys
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
sys.path.append(r"C:\Users\4019-tjyen\Desktop\plotlib\Visualization\yunchieh_plotlib")
print(sys.path)
# Out:
# ['c:\\Users\\4019-tjyen\\Desktop\\Lab_result', 'c:\\Users\\4019-tjyen\\anaconda\\python312.zip', 'c:\\Users\\4019-tjyen\\anaconda\\DLLs', 'c:\\Users\\4019-tjyen\\anaconda\\Lib', 'c:\\Users\\4019-tjyen\\anaconda', '', 'c:\\Users\\4019-tjyen\\anaconda\\Lib\\site-packages', 'c:\\Users\\4019-tjyen\\anaconda\\Lib\\site-packages\\win32', 'c:\\Users\\4019-tjyen\\anaconda\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\4019-tjyen\\anaconda\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\4019-tjyen\\Desktop\\plotlib\\Visualization\\yunchieh_plotlib']

# %%
# Import module 
from Plot_function import plot_error_bar

# %%
from infer_layout_settings import *
from infer_legend_settings import *

# %%
# Load file
data = pd.read_csv(r"C:\Users\4019-tjyen\Downloads\infer_results_02012024.csv", sep="\t")

# %%
# mean and std for each epoch
summary = data.groupby("epoch")["num_links"].agg(["mean", "std"]).reset_index()

# %%
# 1.96 * std
summary["1.96_std"] = 1.96 * summary["std"]

# %%
data_unique = data.merge(summary[["epoch", "mean", "1.96_std"]], on="epoch", how="left")

# %%
data_unique = data_unique.drop_duplicates(subset=["epoch", "mean", "1.96_std"])

# %%
print(data_unique)
# Out:
#       epoch  num_links  ks_pvalue  ks_stat  infer_time       mean   1.96_std
# 0        24  54.000000   0.716647     0.14    3.181993  34.490000  13.636296
# 100      49  41.000000   0.966746     0.10    2.694381  41.375000   6.270229
# 200      74  42.000000   0.869262     0.12    2.711025  44.950000   4.572273
# 300      99  45.000000   0.999995     0.06    2.705329  43.339985   6.483985
# 400     124  41.500000   0.869262     0.12    2.697895  43.564414   5.853294
# 500     149  41.000000   0.869262     0.12    2.696346  44.299403   5.094829
# 600     174  46.000000   0.869262     0.12    2.690243  44.195000   5.571463
# 700     199  47.000000   0.067795     0.26    2.704380  46.070000   4.129741
# 800     224  47.000000   0.395940     0.18    2.692098  44.725000   5.463294
# 900     249  43.500000   0.966746     0.10    2.704717  45.675305   4.060480
# 1000    274  47.000000   0.869262     0.12    2.702657  46.645714   4.086122
# 1100    299  44.000000   0.716647     0.14    2.711230  45.745000   4.405862
# 1200    324  48.000000   0.716647     0.14    2.701003  46.250000   4.074117
# 1300    349  45.006824   0.271914     0.20    2.691943  44.630068   5.334378
# 1400    374  44.000000   0.716647     0.14    2.697607  45.168269   3.986129
# 1500    399  44.000000   0.869262     0.12    2.697445  45.437708   4.422405
# 1600    424  45.000000   0.869262     0.12    2.691878  45.522585   4.622800
# 1700    449  43.000000   0.548685     0.16    2.694720  45.175952   4.940914
# 1800    474  44.000000   0.966746     0.10    2.699157  45.350000   4.691651
# 1900    499  46.000000   0.716647     0.14    2.697369  46.235459   4.069370
# 2000    524  47.000000   0.716647     0.14    2.695264  45.603587   4.047220
# 2100    549  48.000000   0.716647     0.14    2.695849  45.690621   4.257773
# 2200    574  48.000000   0.966746     0.10    2.692147  45.775356   3.302395
# 2300    599  43.500000   0.716647     0.14    2.692519  45.523523   4.456983
# 2400    624  50.000000   0.997711     0.08    2.699292  45.987479   3.885479
# 2500    649  45.500000   0.548685     0.16    2.692575  45.287585   4.164325
# 2600    674  41.000000   0.271914     0.20    2.692007  45.895959   4.253180
# 2700    699  47.000000   0.112385     0.24    2.690276  45.875005   4.510035
# 2800    724  45.000000   0.869262     0.12    2.702622  45.220000   3.488735
# 2900    749  44.000000   0.395940     0.18    2.696923  45.940000   3.709645
# 3000    774  43.000000   0.395940     0.18    2.692159  45.550000   4.278528
# 3100    799  44.000000   0.112385     0.24    2.701793  46.065520   3.595412
# 3200    824  47.000000   0.178587     0.22    2.695786  45.960000   4.150034
# 3300    849  45.500000   0.112385     0.24    2.696036  45.600000   3.687928
# 3400    874  44.000000   0.178587     0.22    2.706000  45.690000   3.558827
# 3500    899  48.000000   0.997711     0.08    2.707252  45.991335   3.674807
# 3600    924  43.000000   0.395940     0.18    2.698683  45.573070   4.009519
# 3700    949  43.000000   0.395940     0.18    2.706299  45.762880   3.840638
# 3800    974  46.000000   0.548685     0.16    2.690656  45.825006   4.123507
# 3900    999  46.500000   0.271914     0.20    2.734388  46.010000   3.613471

# %%
print(data_unique.head())
# Out:
#      epoch  num_links  ks_pvalue  ks_stat  infer_time       mean   1.96_std
# 0       24       54.0   0.716647     0.14    3.181993  34.490000  13.636296
# 100     49       41.0   0.966746     0.10    2.694381  41.375000   6.270229
# 200     74       42.0   0.869262     0.12    2.711025  44.950000   4.572273
# 300     99       45.0   0.999995     0.06    2.705329  43.339985   6.483985
# 400    124       41.5   0.869262     0.12    2.697895  43.564414   5.853294

# %%
# Check missing value
print(data_unique.isna().sum())
# Out:
# epoch         0
# num_links     0
# ks_pvalue     0
# ks_stat       0
# infer_time    0
# mean          0
# 1.96_std      0
# dtype: int64

# %%
# Plot Result

# First Plot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(22,12), gridspec_kw={"hspace":0.4})

plot_error_bar(
    ax1, data_unique, x_col="epoch", y_col="mean", error_col="1.96_std",
    set_xlabel="Epoch", set_ylabel="Num Links",
    tick_params={"direction": "in", "length": 6, "width" : 1},
)


ax1.plot([], [], "o", label="Mean ± 1.96 × Std") 

ax1.legend(
    handles= custom_legend,
    labels=ax1_legend_labels,
    loc= "lower left",
    bbox_to_anchor=(0.8, 0.1),
    fontsize=legend_fontsize,
    **legend_kwarg
)

handles, labels = ax1.get_legend_handles_labels()
print("Handles:", handles)
print("Labels:", labels)

# Second Plot

data["p_value_category"] = (data["ks_pvalue"] > 0.05).astype(int)

#print(data) 

epoch_grouped = data.groupby("epoch")["p_value_category"].value_counts(normalize=True).unstack(fill_value=0)

#print(epoch_grouped)


epoch_grouped.plot(kind="bar", stacked=True, ax=ax2, color=colors, width=0.8)

ax2.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y * 100:.0f}%'))

ax2.set_xlabel("Epoch")
ax2.set_title("P-Value")
ax2.tick_params(axis="x",rotation=0)


# Legend settings
ax2.legend(
    title="p-value Category",
    labels=ax2_legend_labels,
    loc=legend_loc,
    bbox_to_anchor=bbox_to_anchor,
    fontsize=legend_fontsize,
    **legend_kwarg
)


       
plt.tight_layout()
plt.savefig(save_file_name, format="png", dpi="figure", bbox_inches="tight")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting on axes: Axes(0.125,0.559167;0.775x0.320833)
# Handles: [<matplotlib.lines.Line2D object at 0x000002048A8ADCA0>]
# Labels: ['Mean ± 1.96 × Std']
# C:\Users\4019-tjyen\AppData\Local\Temp\ipykernel_80868\2052912922.py:60: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
